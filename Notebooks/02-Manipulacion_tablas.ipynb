# %%
import pandas as pd
import numpy as np
# Out:
# La ejecución de celdas con '.analitica (3.12.1) (Python 3.12.1)' requiere el paquete ipykernel.
#
# Instale "ipykernel" en el entorno de Python.
#
# Comando: "/workspaces/Analisis-de-datos-UQ/.analitica/bin/python -m pip install ipykernel -U --force-reinstall"
