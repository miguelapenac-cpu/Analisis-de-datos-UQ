# %%
import pandas as pd
import numpy as np

# %%
#Caracteristicas generales, seguridad social en salud y educacion

# Links a los conjuntos de datos
url_cgsse ='https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/cgsse.CSV'
url_ocupados = 'https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Ocupados.CSV'
url_ft ='https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV'
url_desocupados = 'https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/No%20ocupados.CSV'

# %%
# CGSSE
df_cgsse = pd.read_csv(url_cgsse, encoding='latin-1', sep=';', 
                       low_memory=False)

#Ocupados
df_ocupados=pd.read_csv(url_ocupados,encoding='latin-1',sep=';',
                        low_memory=False)

#Fuerza de trabajo
df_ft=pd.read_csv(url_ft,
                  encoding='latin-1',sep=';',low_memory=False)
#No ocupados
df_d=pd.read_csv(url_desocupados,encoding='latin-1',
                           sep=';',low_memory=False)

# %%
df_cgsse
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     10
# 1      20250626    6  2025     8238974            1      2      1     10
# 2      20250626    6  2025     8238975            1      1      1     10
# 3      20250626    6  2025     8238975            1      2      1     10
# 4      20250626    6  2025     8238975            1      3      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 67851  20250626    6  2025     8283060            1      1      1     10
# 67852  20250626    6  2025     8283060            1      2      1     10
# 67853  20250626    6  2025     8283062            1      1      1     10
# 67854  20250626    6  2025     8283062            1      2      1     10
# 67855  20250626    6  2025     8283062            1      3      1     10
#
#        AREA  CLASE  ...  P6170  P3041  P3042  P3042S1  P3042S2  P3043  \
# ...

# %%
df_cgsse['FEX_C18'].sum()
# Out:
# np.float64(52045001.000009045)

# %%
df_ft
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     50
# 1      20250626    6  2025     8238974            1      2      1     50
# 2      20250626    6  2025     8238975            1      1      1     50
# 3      20250626    6  2025     8238975            1      2      1     50
# 4      20250626    6  2025     8238975            1      3      1     50
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 54445  20250626    6  2025     8283060            1      1      1     50
# 54446  20250626    6  2025     8283060            1      2      1     50
# 54447  20250626    6  2025     8283062            1      1      1     50
# 54448  20250626    6  2025     8283062            1      2      1     50
# 54449  20250626    6  2025     8283062            1      3      1     50
#
#        AREA  CLASE  ...  P3362S8  P3362S7A1  P6300  P6310  P6310S1  P6320  \
# ...

# %%
df_ocupados
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     60
# 1      20250626    6  2025     8238974            1      2      1     60
# 2      20250626    6  2025     8238975            1      1      1     60
# 3      20250626    6  2025     8238975            1      3      1     60
# 4      20250626    6  2025     8238976            1      1      1     60
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 29701  20250626    6  2025     8283057            1      3      1     60
# 29702  20250625    6  2025     8283058            1      1      1     60
# 29703  20250625    6  2025     8283058            1      2      1     60
# 29704  20250626    6  2025     8283060            1      2      1     60
# 29705  20250626    6  2025     8283062            1      1      1     60
#
#        AREA  CLASE  ...  P1881  P1881S1  P1882  P7240  P7240S1  OCI  \
# ...

# %%
df_d
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238975            1      2      1     70
# 1      20250626    6  2025     8238978            1      1      1     70
# 2      20250626    6  2025     8238980            1      2      1     70
# 3      20250626    6  2025     8238981            1      2      1     70
# 4      20250626    6  2025     8238983            1      2      1     70
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 24739  20250626    6  2025     8283056            1      1      1     70
# 24740  20250626    6  2025     8283059            1      1      1     70
# 24741  20250626    6  2025     8283060            1      1      1     70
# 24742  20250626    6  2025     8283062            1      2      1     70
# 24743  20250626    6  2025     8283062            1      3      1     70
#
#        AREA  CLASE  ...  P1519  P1883  P7422  P7422S1  OFICIO1_C8  OFICIO2_C8  \
# ...

# %%
PT =  df_cgsse['FEX_C18'].sum()
print(f' La población total de referencia para Colombia basado en el modulo cgsse de la GEIH y el factor de expansión es {PT}')
# Out:
#  La población total de referencia para Colombia basado en el modulo cgsse de la GEIH y el factor de expansión es 52045001.000009045

# %%
# en edad de trabajar P6040 :  ¿cuántos años cumplidos tiene...?
df_cgsse[df_cgsse['P6040']>=15]['FEX_C18'].sum()
# Out:
# np.float64(40653416.00000409)

# %%
# Población menor de 15 años
no_pet = df_cgsse[df_cgsse['P6040'] < 15]['FEX_C18'].sum()

print("Población que no está en edad de trabajar:", no_pet)
# Out:
# Población que no está en edad de trabajar: 11391585.000004958

# %%
#FT: Pertenece a la PEA: .sum()si: 1
PEA=df_ft[(df_ft['FT']==1)]['FEX_C18'].sum()
print(f'Población Economicamente Activa {PEA}')
# Out:
# Población Economicamente Activa 25974846.22356785

# %%
#FFT Pertenece a la PEI  si:1
PEI=df_ft[(df_ft['FFT']==1)]['FEX_C18'].sum()
print(f'Población Economicamente Inactiva {PEI}')
# Out:
# Población Economicamente Inactiva 14678569.776436238

# %%
#OCI : Ocupado ? 1:si
O=df_ocupados[(df_ocupados['OCI']==1)]['FEX_C18'].sum()
print(f'Población Ocupada {O}')
# Out:
# Población Ocupada 23752952.660255846

# %%
#OCI : Ocupado ? 1:si
D=df_desocupados[(df_desocupados['DSI']==1)]['FEX_C18'].sum()
print(f'Población No ocupada {D}')
# Out:
# Población No ocupada 2221893.563312005

# %%
TO=O/PET*100
print(f' Tasa de ocupacion 2025 {round(TO,1)}')
# Out:
#  Tasa de ocupacion 2025 58.4

# %%
TD=D/PEA*100
print(f' Tasa de desempleo 2025 : {round(TD,1)}')
# Out:
#  Tasa de desempleo 2025 : 8.6

# %% [markdown]
# Punto 2

# %%
#Primero hay que anexar la p3271 a la tabla de desempleados
df_d = pd.merge(df_d, df_cgsse[['DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'P3271','P6040']], 
                        on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how='left')

df_ft = pd.merge(df_ft, df_cgsse[['DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'P3271','P6040']], 
                        on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how='left')

# %% [markdown]
# QUINDIO

# %%
# 1. Calcular cantidad de hombres desempleados en el quindío 
HDQ = df_d[(df_d['DSI']==1) & (df_d['DPTO']==63) & (df_d['P3271']==1)]['FEX_C18'].sum()
print(f'Hombres Desempleados en el Quindio: {HDQ}')

# 2. Calcular cantidad de hombres en la PEA del quindío
PEAHQ = df_ft[(df_ft['FT']==1) & (df_ft['DPTO']==63) & (df_ft['P3271']==1) ]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa de hombres en el quindío: {PEAHQ}')

# 3. Calcular la tasa de desempleo en hombres del quindío
TDHQ = HDQ/PEAHQ
print(f'Tasa de Desempleo en hombres del quindío: {TDHQ*100}%')
# Out:
# Hombres Desempleados en el Quindio: 17869.520960767004
# Poblacion Economicamente Activa de hombres en el quindío: 174625.87195169798
# Tasa de Desempleo en hombres del quindío: 10.233031773040919%

# %%
# 1. Calcular cantidad de MUJERES desempleadas en el quindío 
MDQ = df_d[(df_d['DSI']==1) & (df_d['DPTO']==63) & (df_d['P3271']==2)]['FEX_C18'].sum()
print(f'Mujeres Desempleadas en el Quindio: {MDQ}')

# 2. Calcular cantidad de mujeres en la PEA del quindío
PEAMQ = df_ft[(df_ft['FT']==1) & (df_ft['DPTO']==63) & (df_ft['P3271']==2) ]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa de mujeres en el quindío: {PEAMQ}')

# 3. Calcular la tasa de desempleo en mujeres del quindío
TDMQ = MDQ/PEAMQ
print(f'Tasa de Desempleo en mujeres del quindío: {TDMQ*100}%')
# Out:
# Mujeres Desempleadas en el Quindio: 10618.534945967001
# Poblacion Economicamente Activa de mujeres en el quindío: 116885.879263648
# Tasa de Desempleo en mujeres del quindío: 9.084531863781265%

# %% [markdown]
# RISARALDA

# %%
# 1. Calcular cantidad de hombres desempleados 
HDQ = df_d[(df_d['DSI']==1) & (df_d['DPTO']==66) & (df_d['P3271']==1)]['FEX_C18'].sum()
print(f'Hombres Desempleados en el Risaralda: {HDQ}')

# 2. Calcular cantidad de hombres en la PEA
PEAHQ = df_ft[(df_ft['FT']==1) & (df_ft['DPTO']==66) & (df_ft['P3271']==1) ]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa de hombres en el Risaralda: {PEAHQ}')

# 3. Calcular la tasa de desempleo en hombres
TDHQ = HDQ/PEAHQ
print(f'Tasa de Desempleo en hombres del Risaralda: {TDHQ*100}%')
# Out:
# Hombres Desempleados en el Risaralda: 18000.60370715
# Poblacion Economicamente Activa de hombres en el Risaralda: 296342.328368219
# Tasa de Desempleo en hombres del Risaralda: 6.074260064793518%

# %%
# 1. Calcular cantidad de MUJERES desempleadas 
MDQ = df_d[(df_d['DSI']==1) & (df_d['DPTO']==66) & (df_d['P3271']==2)]['FEX_C18'].sum()
print(f'Mujeres Desempleadas en el Risaralda: {MDQ}')

# 2. Calcular cantidad de mujeres en la PEA
PEAMQ = df_ft[(df_ft['FT']==1) & (df_ft['DPTO']==66) & (df_ft['P3271']==2) ]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa de mujeres en el Risaralda: {PEAMQ}')

# 3. Calcular la tasa de desempleo en mujeres
TDMQ = MDQ/PEAMQ
print(f'Tasa de Desempleo en mujeres del Risaralda: {TDMQ*100}%')
# Out:
# Mujeres Desempleadas en el Risaralda: 21676.799766712
# Poblacion Economicamente Activa de mujeres en el Risaralda: 203157.903399127
# Tasa de Desempleo en mujeres del Risaralda: 10.669926891362644%

# %% [markdown]
# CALDAS

# %%
# 1. Calcular cantidad de hombres desempleados 
HDQ = df_d[(df_d['DSI']==1) & (df_d['DPTO']==17) & (df_d['P3271']==1)]['FEX_C18'].sum()
print(f'Hombres Desempleados en el Risaralda: {HDQ}')

# 2. Calcular cantidad de hombres en la PEA
PEAHQ = df_ft[(df_ft['FT']==1) & (df_ft['DPTO']==17) & (df_ft['P3271']==1) ]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa de hombres en el Risaralda: {PEAHQ}')

# 3. Calcular la tasa de desempleo en hombres
TDHQ = HDQ/PEAHQ
print(f'Tasa de Desempleo en hombres del Risaralda: {TDHQ*100}%')
# Out:
# Hombres Desempleados en el Risaralda: 18226.160047418998
# Poblacion Economicamente Activa de hombres en el Risaralda: 326447.467769983
# Tasa de Desempleo en hombres del Risaralda: 5.5831831601957065%

# %%
# 1. Calcular cantidad de MUJERES desempleadas 
MDQ = df_d[(df_d['DSI']==1) & (df_d['DPTO']==17) & (df_d['P3271']==2)]['FEX_C18'].sum()
print(f'Mujeres Desempleadas en el Caldas: {MDQ}')

# 2. Calcular cantidad de mujeres en la PEA
PEAMQ = df_ft[(df_ft['FT']==1) & (df_ft['DPTO']==17) & (df_ft['P3271']==2) ]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa de mujeres en el Caldas: {PEAMQ}')

# 3. Calcular la tasa de desempleo en mujeres
TDMQ = MDQ/PEAMQ
print(f'Tasa de Desempleo en mujeres del Caldas: {TDMQ*100}%')
# Out:
# Mujeres Desempleadas en el Risaralda: 17214.491449226003
# Poblacion Economicamente Activa de mujeres en el Risaralda: 224206.533775
# Tasa de Desempleo en mujeres del Risaralda: 7.677961547053494%

# %% [markdown]
# TOLIMA

# %%
# 1. Calcular cantidad de hombres desempleados 
HDQ = df_d[(df_d['DSI']==1) & (df_d['DPTO']==73) & (df_d['P3271']==1)]['FEX_C18'].sum()
print(f'Hombres Desempleados en el Tolima: {HDQ}')

# 2. Calcular cantidad de hombres en la PEA
PEAHQ = df_ft[(df_ft['FT']==1) & (df_ft['DPTO']==73) & (df_ft['P3271']==1) ]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa de hombres en el Tolima: {PEAHQ}')

# 3. Calcular la tasa de desempleo en hombres
TDHQ = HDQ/PEAHQ
print(f'Tasa de Desempleo en hombres del Tolima: {TDHQ*100}%')
# Out:
# Hombres Desempleados en el Tolima: 28255.96613253
# Poblacion Economicamente Activa de hombres en el Tolima: 391325.28931057
# Tasa de Desempleo en hombres del Tolima: 7.220582697916321%

# %%
# 1. Calcular cantidad de MUJERES desempleadas 
MDQ = df_d[(df_d['DSI']==1) & (df_d['DPTO']==73) & (df_d['P3271']==2)]['FEX_C18'].sum()
print(f'Mujeres Desempleadas en el Caldas: {MDQ}')

# 2. Calcular cantidad de mujeres en la PEA
PEAMQ = df_ft[(df_ft['FT']==1) & (df_ft['DPTO']==73) & (df_ft['P3271']==2) ]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa de mujeres en el Caldas: {PEAMQ}')

# 3. Calcular la tasa de desempleo en mujeres
TDMQ = MDQ/PEAMQ
print(f'Tasa de Desempleo en mujeres del Caldas: {TDMQ*100}%')
# Out:
# Mujeres Desempleadas en el Caldas: 52100.16756370999
# Poblacion Economicamente Activa de mujeres en el Caldas: 271316.21571268
# Tasa de Desempleo en mujeres del Caldas: 19.20274740190366%

# %% [markdown]
# El departamento con la tasa con mayor desempleo para hombre es

# %% [markdown]
# PUNTO 3 Quindio

# %%
#Segmento de 18 a 24 años de edad

# 1. Calcular cantidad personas desempleadas entre los 18 - 24 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=18) & (df_d['P6040']<=24) & (df_d['DPTO']==63)]['FEX_C18'].sum()
print(f'Personas Desempleadas en el quindío entre los 18 - 24 años: {D1824}')

# 2. Calcular cantidad personas en la PEA entre los 18 - 24
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=18) & (df_ft['P6040']<=24) & (df_ft['DPTO']==63)]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa en el quindío entre los 18 - 24 años: {PEA1824}')

# 3. Calcular la tasa de desempleo en personas entre los 18 - 24 del quindío
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo en personas entre los 18 - 24 del quindío: {TD1824*100}%')
# Out:
# Personas Desempleadas en el quindío entre los 18 - 24 años: 3819.2724449800003
# Poblacion Economicamente Activa en el quindío entre los 18 - 24 años: 29912.663758397
# Tasa de Desempleo en personas entre los 18 - 24 del quindío: 12.768078683423386%

# %%
#Segmento de 18 a 24 años de edad

# 1. Calcular cantidad personas desempleadas entre los 18 - 24 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=24) & (df_d['P6040']<=30) & (df_d['DPTO']==63)]['FEX_C18'].sum()
print(f'Personas Desempleadas en el quindío entre los 18 - 24 años: {D1824}')

# 2. Calcular cantidad personas en la PEA entre los 18 - 24
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=24) & (df_ft['P6040']<=30) & (df_ft['DPTO']==63)]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa en el quindío entre los 18 - 24 años: {PEA1824}')

# 3. Calcular la tasa de desempleo en personas entre los 18 - 24 del quindío
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo en personas entre los 18 - 24 del quindío: {TD1824*100}%')
# Out:
# Personas Desempleadas en el quindío entre los 18 - 24 años: 7008.068900358
# Poblacion Economicamente Activa en el quindío entre los 18 - 24 años: 51117.425383347
# Tasa de Desempleo en personas entre los 18 - 24 del quindío: 13.709745449427672%

# %%
#Segmento de 18 a 24 años de edad

# 1. Calcular cantidad personas desempleadas entre los 18 - 24 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=30) & (df_d['P6040']<=40) & (df_d['DPTO']==63)]['FEX_C18'].sum()
print(f'Personas Desempleadas en el quindío entre los 18 - 24 años: {D1824}')

# 2. Calcular cantidad personas en la PEA entre los 18 - 24
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=30) & (df_ft['P6040']<=40) & (df_ft['DPTO']==63)]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa en el quindío entre los 18 - 24 años: {PEA1824}')

# 3. Calcular la tasa de desempleo en personas entre los 18 - 24 del quindío
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo en personas entre los 18 - 24 del quindío: {TD1824*100}%')
# Out:
# Personas Desempleadas en el quindío entre los 18 - 24 años: 7015.512022579001
# Poblacion Economicamente Activa en el quindío entre los 18 - 24 años: 72731.96687714598
# Tasa de Desempleo en personas entre los 18 - 24 del quindío: 9.645706453159914%

# %%
#Segmento de 18 a 24 años de edad

# 1. Calcular cantidad personas desempleadas entre los 18 - 24 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=40) & (df_d['P6040']<=50) & (df_d['DPTO']==63)]['FEX_C18'].sum()
print(f'Personas Desempleadas en el quindío entre los 18 - 24 años: {D1824}')

# 2. Calcular cantidad personas en la PEA entre los 18 - 24
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=40) & (df_ft['P6040']<=50) & (df_ft['DPTO']==63)]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa en el quindío entre los 18 - 24 años: {PEA1824}')

# 3. Calcular la tasa de desempleo en personas entre los 18 - 24 del quindío
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo en personas entre los 24 - 30 del quindío: {TD1824*100}%')
# Out:
# Personas Desempleadas en el quindío entre los 18 - 24 años: 4416.562673204001
# Poblacion Economicamente Activa en el quindío entre los 18 - 24 años: 70586.28939453498
# Tasa de Desempleo en personas entre los 18 - 24 del quindío: 6.256969605695048%

# %%
# 1.
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=60) & (df_d['DPTO']==63)]['FEX_C18'].sum()
print(f'Personas Desempleadas en el quindío 60 en adelante: {D1824}')

# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=60) & (df_ft['DPTO']==63)]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa en el quindío 60 en adelante: {PEA1824}')

# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo en personas entre los 60 en adelante del quindío: {TD1824*100}%')
# Out:
# Personas Desempleadas en el quindío 60 en adelante: 4297.130465619
# Poblacion Economicamente Activa en el quindío 60 en adelante: 41690.707895215004
# Tasa de Desempleo en personas entre los 60 en adelante del quindío: 10.307165991086942%

# %% [markdown]
# Risaralda

# %%
# 1. 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=18) & (df_d['P6040']<=24) & (df_d['DPTO']==66)]['FEX_C18'].sum()
print(f'Personas Desempleadas entre los 18 - 24: {D1824}')

# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=18) & (df_ft['P6040']<=24) & (df_ft['DPTO']==66)]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa entre los 18 - 24: {PEA1824}')

# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo en personas entre los 18 - 24: {TD1824*100}%')
# Out:
# Personas Desempleadas en el quindío entre los 18 - 24: 9385.755003442
# Poblacion Economicamente Activa en el quindío entre los 18 - 24: 63454.922070486005
# Tasa de Desempleo en personas entre los 18 - 24: 14.79121665773423%

# %%
# 1. 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=24) & (df_d['P6040']<=30) & (df_d['DPTO']==66)]['FEX_C18'].sum()
print(f'Personas Desempleadas en el quindío entre los 18 - 24: {D1824}')

# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=24) & (df_ft['P6040']<=30) & (df_ft['DPTO']==66)]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa en el quindío entre los 18 - 24: {PEA1824}')

# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo en personas entre los 18 - 24: {TD1824*100}%')
# Out:
# Personas Desempleadas en el quindío entre los 18 - 24: 10504.69809363
# Poblacion Economicamente Activa en el quindío entre los 18 - 24: 90684.88337600001
# Tasa de Desempleo en personas entre los 18 - 24: 11.5837366742538%

# %%
# 1. 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=30) & (df_d['P6040']<=40) & (df_d['DPTO']==66)]['FEX_C18'].sum()
print(f'Personas Desempleadas: {D1824}')

# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=30) & (df_ft['P6040']<=40) & (df_ft['DPTO']==66)]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa: {PEA1824}')

# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo: {TD1824*100}%')
# Out:
# Personas Desempleadas: 9922.605545110002
# Poblacion Economicamente Activa: 153899.63411428098
# Tasa de Desempleo: 6.447452329705859%

# %%
# 1. 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=40) & (df_d['P6040']<=50) & (df_d['DPTO']==66)]['FEX_C18'].sum()


# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=40) & (df_ft['P6040']<=50) & (df_ft['DPTO']==66)]['FEX_C18'].sum()


# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo: {TD1824*100}%')
# Out:
# Tasa de Desempleo: 7.3356816001245955%

# %%
# 1. 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=60) & (df_d['DPTO']==66)]['FEX_C18'].sum()


# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=60) & (df_ft['DPTO']==66)]['FEX_C18'].sum()


# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo: {TD1824*100}%')
# Out:
# Tasa de Desempleo: 3.6398607318240614%

# %% [markdown]
# CALDAS

# %%
# 1. 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=18) & (df_d['P6040']<=24) & (df_d['DPTO']==17)]['FEX_C18'].sum()


# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=18) & (df_ft['P6040']<=24) & (df_ft['DPTO']==17)]['FEX_C18'].sum()


# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo: {TD1824*100}%')
# Out:
# Tasa de Desempleo: 9.344949005517167%

# %%
# 1. 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=24) & (df_d['P6040']<=30) & (df_d['DPTO']==17)]['FEX_C18'].sum()


# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=24) & (df_ft['P6040']<=30) & (df_ft['DPTO']==17)]['FEX_C18'].sum()


# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo: {TD1824*100}%')
# Out:
# Tasa de Desempleo: 6.442118267858205%

# %%
# 1. 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=30) & (df_d['P6040']<=40) & (df_d['DPTO']==17)]['FEX_C18'].sum()


# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=30) & (df_ft['P6040']<=40) & (df_ft['DPTO']==17)]['FEX_C18'].sum()


# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo: {TD1824*100}%')
# Out:
# Tasa de Desempleo: 5.719162060970324%

# %%
# 1. 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=40) & (df_d['P6040']<=50) & (df_d['DPTO']==17)]['FEX_C18'].sum()


# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=40) & (df_ft['P6040']<=50) & (df_ft['DPTO']==17)]['FEX_C18'].sum()


# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo: {TD1824*100}%')
# Out:
# Tasa de Desempleo: 5.123140786732679%

# %%
# 1. 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=60) & (df_d['DPTO']==17)]['FEX_C18'].sum()


# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=60) & (df_ft['DPTO']==17)]['FEX_C18'].sum()


# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo: {TD1824*100}%')
# Out:
# Tasa de Desempleo: 4.060989381499756%

# %% [markdown]
# Tolima

# %%
# 1. 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=18) & (df_d['P6040']<=24) & (df_d['DPTO']==73)]['FEX_C18'].sum()


# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=18) & (df_ft['P6040']<=24) & (df_ft['DPTO']==73)]['FEX_C18'].sum()


# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo: {TD1824*100}%')
# Out:
# Tasa de Desempleo: 19.817064699055017%

# %%
# 1. 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=24) & (df_d['P6040']<=30) & (df_d['DPTO']==73)]['FEX_C18'].sum()


# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=24) & (df_ft['P6040']<=30) & (df_ft['DPTO']==73)]['FEX_C18'].sum()


# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo: {TD1824*100}%')
# Out:
# Tasa de Desempleo: 13.882960839796077%

# %%
# 1. 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=30) & (df_d['P6040']<=40) & (df_d['DPTO']==73)]['FEX_C18'].sum()


# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=30) & (df_ft['P6040']<=40) & (df_ft['DPTO']==73)]['FEX_C18'].sum()


# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo: {TD1824*100}%')
# Out:
# Tasa de Desempleo: 12.247228061873246%

# %%
# 1. 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=40) & (df_d['P6040']<=50) & (df_d['DPTO']==73)]['FEX_C18'].sum()


# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=40) & (df_ft['P6040']<=50) & (df_ft['DPTO']==73)]['FEX_C18'].sum()


# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo: {TD1824*100}%')
# Out:
# Tasa de Desempleo: 8.641041526465289%

# %%
# 1. 
D1824 = df_d[(df_d['DSI']==1) & (df_d['P6040']>=60) & (df_d['DPTO']==73)]['FEX_C18'].sum()


# 2.
PEA1824 = df_ft[(df_ft['FT']==1) & (df_ft['P6040']>=60) & (df_ft['DPTO']==73)]['FEX_C18'].sum()


# 3.
TD1824 = D1824/PEA1824
print(f'Tasa de Desempleo: {TD1824*100}%')
# Out:
# Tasa de Desempleo: 9.458632182113549%

# %% [markdown]
# 4. Quindio
